# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
CREATE WIDGET TEXT storageName default="adlsentregafinal"

# %%
# %python
storageName = dbutils.widgets.get("storageName")

# %% [markdown]
# ##Tablas Golden

# %%
# %sql
DROP TABLE IF EXISTS retail_dev.golden.resumen_retail;

# %% [markdown]
# ##Tablas Silver

# %%
# %sql
DROP TABLE IF EXISTS retail_dev.silver.ventas_detalle_limpias;
DROP TABLE IF EXISTS retail_dev.silver.inventario_limpio;

# %% [markdown]
# ##Tablas Bronze

# %%
# %sql
DROP TABLE IF EXISTS retail_dev.bronze.clientes;
DROP TABLE IF EXISTS retail_dev.bronze.productos;
DROP TABLE IF EXISTS retail_dev.bronze.ordenes;
DROP TABLE IF EXISTS retail_dev.bronze.detalle_ordenes;
DROP TABLE IF EXISTS retail_dev.bronze.inventario;

# %% [markdown]
# ##Esquemas

# %%
# %sql
DROP SCHEMA IF EXISTS retail_dev.raw;
DROP SCHEMA IF EXISTS retail_dev.bronze;
DROP SCHEMA IF EXISTS retail_dev.silver;
DROP SCHEMA IF EXISTS retail_dev.golden;

# %% [markdown]
# ##Catálogo

# %%
# %sql
DROP CATALOG IF EXISTS retail_dev CASCADE;

# %% [markdown]
# ##Rutas Físicas

# %%
# dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/", True)
# dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/", True)
# dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/", True)

# %% [markdown]
# ## External Location

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-metastore` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-raw` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-bronze` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-silver` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-golden` FORCE;
